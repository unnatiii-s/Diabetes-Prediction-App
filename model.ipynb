# %%
# importing libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import joblib

# %%
from tensorflow import keras

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# divide the datatset into dependent and independent variables
X = df.drop(columns = "Outcome")
y = df["Outcome"]

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72  ...  33.6                     0.627   50
# 1            1       85             66  ...  26.6                     0.351   31
# 2            8      183             64  ...  23.3                     0.672   32
# 3            1       89             66  ...  28.1                     0.167   21
# 4            0      137             40  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
# normalize the feature
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# save the scaler
joblib.dump(scaler,"Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
# dividing the dataset into training and testing
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

# %%
# build a neural network
model = keras.Sequential([
    keras.layers.Dense(16,activation = "relu",input_shape = (X.shape[1],)), # input layer
    keras.layers.Dense(8,activation = "relu"),# hidden layer
    keras.layers.Dense(1,activation = "sigmoid") # output layer
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compiling the model
model.compile(optimizer = "adam",loss ="binary_crossentropy")

# %%
# train the model
model.fit(X_train,y_train,epochs = 50,batch_size = 10,validation_data = (X_test,y_test))
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.6790 - val_loss: 0.6377
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6072 - val_loss: 0.5959
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5837 - val_loss: 0.5639
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5214 - val_loss: 0.5395
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5187 - val_loss: 0.5203
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5030 - val_loss: 0.5084
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4727 - val_loss: 0.5005
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4291 - val_loss: 0.4971
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4657 - val_loss: 0.4934
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4511 - val_loss: 0.4894
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4726 - val_loss: 0.4879
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4456 - val_loss: 0.4860
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4632 - val_loss: 0.4828
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4695 - val_loss: 0.4815
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4630 - val_loss: 0.4798
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4784 - val_loss: 0.4792
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4350 - val_loss: 0.4779
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4344 - val_loss: 0.4771
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4528 - val_loss: 0.4756
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4362 - val_loss: 0.4766
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4332 - val_loss: 0.4745
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4472 - val_loss: 0.4746
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4344 - val_loss: 0.4737
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4144 - val_loss: 0.4754
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4346 - val_loss: 0.4738
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4253 - val_loss: 0.4728
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4908 - val_loss: 0.4731
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4166 - val_loss: 0.4733
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4078 - val_loss: 0.4731
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4089 - val_loss: 0.4717
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4439 - val_loss: 0.4706
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4354 - val_loss: 0.4728
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4640 - val_loss: 0.4702
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4281 - val_loss: 0.4719
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3820 - val_loss: 0.4721
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4726 - val_loss: 0.4702
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4042 - val_loss: 0.4704
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4406 - val_loss: 0.4683
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4084 - val_loss: 0.4712
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4101 - val_loss: 0.4707
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4478 - val_loss: 0.4702
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4160 - val_loss: 0.4689
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3770 - val_loss: 0.4688
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4122 - val_loss: 0.4692
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4053 - val_loss: 0.4694
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4238 - val_loss: 0.4692
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4413 - val_loss: 0.4687
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3860 - val_loss: 0.4681
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4180 - val_loss: 0.4706
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4504 - val_loss: 0.4682

# %%
y_predict = model.predict(X_test)
y_predict = (y_predict > 0.5).astype("int32")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
accuracy = accuracy_score(y_predict,y_test)
recall = recall_score(y_predict , y_test)
precision = precision_score(y_predict,y_test)
cm = confusion_matrix(y_predict,y_test)
cr = classification_report(y_predict,y_test)

# %%
# Print all the performance metrics
print("the accuracy of our diabetes prediction model is ",accuracy)
print("Recall is ",recall)
print("Precision ",precision)
print("Confusion matrix ",cm)
print("Classification report ",cr)
# Out:
# the accuracy of our diabetes prediction model is  0.8051948051948052
# Recall is  0.7659574468085106
# Precision  0.6545454545454545
# Confusion matrix  [[88 19]
#  [11 36]]
# Classification report                precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85       107
#            1       0.65      0.77      0.71        47
#
#     accuracy                           0.81       154
#    macro avg       0.77      0.79      0.78       154
# weighted avg       0.82      0.81      0.81       154

# %%
model.save("Diabetic_model.h5")
print("model has been saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model has been saved
